# %%
#Q1. Implement Binary tree.

class TreeNode:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key

def insert(root, key):
    if root is None:
        return TreeNode(key)
    else:
        if key < root.val:
            root.left = insert(root.left, key)
        else:
            root.right = insert(root.right, key)
    return root

def inorder_traversal(root):
    if root:
        inorder_traversal(root.left)
        print(root.val)
        inorder_traversal(root.right)

# Example usage:
if __name__ == "__main__":
    root = None
    root = insert(root, 50)
    insert(root, 30)
    insert(root, 20)
    insert(root, 40)
    insert(root, 70)
    insert(root, 60)
    insert(root, 80)

    print("In-order traversal of the binary tree:")
    inorder_traversal(root)
# Out:
# In-order traversal of the binary tree:
# 20
# 30
# 40
# 50
# 60
# 70
# 80

# %%
#Q2. Find height of a given tree.

class Node:
    def __init__(self, value):
        self.value = value
        self.children = []

def find_tree_height(root):
    if root is None:
        return 0
    else:      
        height = 0        
        for child in root.children:
            child_height = find_tree_height(child)            
            if child_height > height:
                height = child_height        
        return height + 1
root = Node(1)
root.children.append(Node(2))
root.children.append(Node(3))
root.children[0].children.append(Node(4))
root.children[0].children.append(Node(5))
root.children[1].children.append(Node(6))

height = find_tree_height(root)
print("Height of the tree:", height)
# Out:
# Height of the tree: 3

# %%
#Q3. Perform Pre-order, Post-order, In-order traversal.

class TreeNode:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None
def preorder_traversal(root):
    if root:
        print(root.value, end=" ")
        preorder_traversal(root.left)
        preorder_traversal(root.right)
def inorder_traversal(root):
    if root:
        inorder_traversal(root.left)
        print(root.value, end=" ")
        inorder_traversal(root.right)
def postorder_traversal(root):
    if root:
        postorder_traversal(root.left)
        postorder_traversal(root.right)
        print(root.value, end=" ")

root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)

print("Pre-order Traversal:")
preorder_traversal(root)

print("\nIn-order Traversal:")
inorder_traversal(root)

print("\nPost-order Traversal:")
postorder_traversal(root)
# Out:
# Pre-order Traversal:
# 1 2 4 5 3
# In-order Traversal:
# 4 2 5 1 3
# Post-order Traversal:
# 4 5 2 3 1

# %%
#Q4. Function to print all the leaves in a given binary tree.

class TreeNode:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

def print_leaf_nodes(root):
    if root is not None:
        if root.left is None and root.right is None:
            print(root.value)  # Print the leaf node
        else:           
            if root.left:
                print_leaf_nodes(root.left)
            if root.right:
                print_leaf_nodes(root.right)

root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)

print("Leaf nodes in the binary tree:")
print_leaf_nodes(root)
# Out:
# Leaf nodes in the binary tree:
# 4
# 5
# 3

# %%
#Q5. Implement BFS (Breath First Search) and DFS (Depth First Search).

class TreeNode:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None
from collections import deque

def bfs(root):
    if root is None:
        return []

    result = []
    queue = deque()
    queue.append(root)

    while queue:
        node = queue.popleft()
        result.append(node.value)

        if node.left:
            queue.append(node.left)
        if node.right:
            queue.append(node.right)

    return result
def dfs_preorder(root):
    if root is None:
        return []

    result = []
    stack = [root]

    while stack:
        node = stack.pop()
        result.append(node.value)

        if node.right:
            stack.append(node.right)
        if node.left:
            stack.append(node.left)

    return result
def dfs_inorder(root):
    if root is None:
        return []

    result = []
    stack = []
    current = root

    while stack or current:
        if current:
            stack.append(current)
            current = current.left
        else:
            current = stack.pop()
            result.append(current.value)
            current = current.right

    return result

root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)

print("BFS traversal:", bfs(root))
print("DFS pre-order traversal:", dfs_preorder(root))
print("DFS in-order traversal:", dfs_inorder(root))
# Out:
# BFS traversal: [1, 2, 3, 4, 5]
# DFS pre-order traversal: [1, 2, 4, 5, 3]
# DFS in-order traversal: [4, 2, 5, 1, 3]

# %%
#Q6. Find sum of all left leaves in a given Binary Tree.

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def sumOfLeftLeaves(root):
    if root is None:
        return 0


    left_leaves_sum = 0
    
    if root.left is not None and root.left.left is None and root.left.right is None:
        left_leaves_sum += root.left.val
    
    left_leaves_sum += sumOfLeftLeaves(root.left)
    left_leaves_sum += sumOfLeftLeaves(root.right)

    return left_leaves_sum

root = TreeNode(3)
root.left = TreeNode(9)
root.right = TreeNode(20)
root.right.left = TreeNode(15)
root.right.right = TreeNode(7)

result = sumOfLeftLeaves(root)

print("Sum of left leaves:", result)
# Out:
# Sum of left leaves: 24

# %%
#Q7. Find sum of all nodes of the given perfect binary tree

class TreeNode:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

def sum_of_nodes(root):
    if root is None:
        return 0
    
    left_sum = sum_of_nodes(root.left)
    right_sum = sum_of_nodes(root.right)
  
    total_sum = root.value + left_sum + right_sum

    return total_sum

root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)
root.right.left = TreeNode(6)
root.right.right = TreeNode(7)

result = sum_of_nodes(root)
print("Sum of all nodes:", result)
# Out:
# Sum of all nodes: 28

# %%
#Q8. Count subtress that sum up to a given value x in a binary tree.

class TreeNode:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

def count_subtrees_with_sum(root, x):
    if root is None:
        return 0

    def count_subtrees_with_sum_helper(node, x):
        if node is None:
            return 0

        count_from_node = 0

        if node.value == x:
            count_from_node = 1


        left_count = count_subtrees_with_sum_helper(node.left, x - node.value)
        right_count = count_subtrees_with_sum_helper(node.right, x - node.value)
    
        total_count = count_from_node + left_count + right_count

        return total_count

    count = count_subtrees_with_sum_helper(root, x)
    return count

root = TreeNode(10)
root.left = TreeNode(5)
root.right = TreeNode(-3)
root.left.left = TreeNode(3)
root.left.right = TreeNode(2)
root.right.right = TreeNode(11)
root.left.left.left = TreeNode(3)
root.left.left.right = TreeNode(-2)
root.left.right.right = TreeNode(1)

x = 8 
result = count_subtrees_with_sum(root, x)
print("Number of subtrees with sum", x, ":", result)
# Out:
# Number of subtrees with sum 8 : 0

# %%
#Q9. Find maximum level sum in Binary Tree.

class TreeNode:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

def max_level_sum(root):
    if root is None:
        return 0

    max_sum = float('-inf') 
    level = 0

    queue = [root]

    while queue:
        level_sum = 0
        level_size = len(queue)

        for i in range(level_size):
            node = queue.pop(0)
            level_sum += node.value

            if node.left:
                queue.append(node.left)
            if node.right:
                queue.append(node.right)

        if level_sum > max_sum:
            max_sum = level_sum

        level += 1

    return max_sum

root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)
root.right.right = TreeNode(6)

result = max_level_sum(root)
print("Maximum level sum:", result)
# Out:
# Maximum level sum: 15

# %%
#Q10. Print the nodes at odd levels of a tree.

class TreeNode:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

def print_nodes_at_odd_levels(root):
    if root is None:
        return

    level = 1  
    queue = [root]

    while queue:
        level_size = len(queue)

        for i in range(level_size):
            node = queue.pop(0)

            if level % 2 == 1:
                print(node.value, end=" ")

            if node.left:
                queue.append(node.left)
            if node.right:
                queue.append(node.right)

        level += 1

root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)
root.left.left = TreeNode(4)
root.left.right = TreeNode(5)
root.right.right = TreeNode(6)

print("Nodes at odd levels:")
print_nodes_at_odd_levels(root)
# Out:
# Nodes at odd levels:
# 1 4 5 6
